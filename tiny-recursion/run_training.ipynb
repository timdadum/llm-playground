# %% [markdown]
# # Run Training (enhanced v2)
# TRM (K=1), TRMSequential (next K), recursive_model (segment traversed T times).

# %%
import sys; print(sys.version)
# !pip -q install -r requirements.txt
# Out:
# 3.9.13 (main, Aug 25 2022, 23:51:50) [MSC v.1916 64 bit (AMD64)]
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\timda\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\timda\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\timda\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\timda\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\timda\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\timda\anaconda3\lib\site-packages)
#
# [notice] A new release of pip is available: 25.2 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# !python -u train.py --model_type gpt --epochs 1 --n_rows 4000 --context_length 256 --seed 42
# Out:
# ^C

# %%
# !python -u train.py --model_type trm_sequential --K 3 --epochs 1 --n_rows 4000 --context_length 260 --seed 7

# %%
# !python -u train.py --model_type recursive_model --T 5 --epochs 1 --n_rows 4000 --context_length 256 --seed 1337
